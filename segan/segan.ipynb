# %%
# !source env/bin/activate

# %%
# !deactivate

# %%
# !pwd

# %%
# %cd segan/
# Out:
# /zfs/store5.hydra.local/user/r/rybakina/sirius/segan_project/segan

# %%
# !../env/bin/pip install -r requirements.txt

# %%
# !../env/bin/python3 -m pip install tensorflow_gpu==1.15.0

# %%
cd ..

# %%
ls ../../../mydataset

# %%
# !../env/bin/pip3 --version

# %%
# !../env/bin/pip install toml

# %%
# !cp ../../denoiser1.1/dataset/debug/noisy/* data/noisy_trainset_wav_16k/

# %%
ls ../../

# %%
# !../env/bin/pip install giggle

# %%
from gigle import Gigle

# %%
index = Giggle.create("index".encode('utf-8'), "HMEC_hg19_BroadHMM_ALL.bed".encode('utf-8'))

# %%
# !echo "import sys; sys.setdefaultencoding('utf-16-be')" > sitecustomize.py

# %%
# !../env/bin/python3 sitecustomize.py

# %%
# !../env/bin/python3 -c 'import sys; print(sys.stdin.encoding, sys.stdout.encoding)'

# %%
# !../env/bin/python3 make_tfrecords.py --force-gen --cfg cfg/e2e_maker.cfg
# Out:
# Will overwrite previously existing tfrecords
# --------------------------------------------------
# Processing wav file 20721/20721 ../../denoiser_project/denoiser/train_10_02/clean/whistle2_4e50013893aa1male.wav
# **************************************************
# Total processing and writing time: 27.348895380971953 s

# %%
rm -r segan_allbiased_preemph

# %%
# !CUDA_VISIBLE_DEVICES="1,2,3" ../env/bin/python3 main.py --init_noise_std 0. --save_path segan_allbiased_preemph \
                                          --init_l1_weight 100. --batch_size 1500 --g_nl prelu \
                                          --save_freq 50 --preemph 0.95 --epoch 10 --bias_deconv True \
                                          --bias_downconv True --bias_D_conv True
# Out:
# 2021-02-13 14:27:51.598239: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-02-13 14:27:51.614672: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2021-02-13 14:27:51.623336: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5592907c29c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-13 14:27:51.623386: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-13 14:27:51.625987: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-02-13 14:27:51.943867: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5592907c4a30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !rm -r ../../noisy_31_01

# %%
# !mkdir outputs_test
# Out:
# mkdir: cannot create directory ‘outputs_test’: File exists

# %%
# !CUDA_VISIBLE_DEVICES="1,2,3" ../env/bin/python3 main.py --init_noise_std 0. --save_path segan_allbiased_preemph \
               --batch_size 64 --g_nl prelu --weights SEGAN-86 \
               --preemph 0.95 --bias_deconv True \
               --bias_downconv True --bias_D_conv True \
               --test_wav ../../dataset31_01/test/noisy/cart5_686d1411a9aa.wav --save_clean_path outputs_test
# Out:
# 2021-02-03 14:06:52.285751: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2021-02-03 14:06:52.317455: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2021-02-03 14:06:52.332352: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556939cf0c90 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-02-03 14:06:52.332453: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-02-03 14:06:52.339168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-02-03 14:06:53.139608: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556939cf2d60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# ...

# %%
# !../env/bin/ clean_wav.sh ../../manifest_classes_27_01_test/noisy outputs_test
# Out:
# /bin/sh: ../env/bin/: Is a directory
